# %%
# !pip install --upgrade scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.26.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.24 in /home/naim/miniconda3/envs/computer-vision/lib/python3.11/site-packages (from scikit-image) (2.4.6)
# Requirement already satisfied: scipy>=1.11.4 in /home/naim/miniconda3/envs/computer-vision/lib/python3.11/site-packages (from scikit-image) (1.17.1)
# Requirement already satisfied: networkx>=3.0 in /home/naim/miniconda3/envs/computer-vision/lib/python3.11/site-packages (from scikit-image) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in /home/naim/miniconda3/envs/computer-vision/lib/python3.11/site-packages (from scikit-image) (12.3.0)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image)
#   Downloading imageio-2.37.4-py3-none-any.whl.metadata (9.6 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image)
#   Downloading tifffile-2026.3.3-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /home/naim/miniconda3/envs/computer-vision/lib/python3.11/site-packages (from scikit-image) (26.3)
# Collecting lazy-loader>=0.4 (from scikit-image)
#   Downloading lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Downloading scikit_image-0.26.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 327.6 kB/s  0:00:38 eta 0:00:010:02:04
# Downloading imageio-2.37.4-py3-none-any.whl (318 kB)
# Downloading lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# Downloading tifffile-2026.3.3-py3-none-any.whl (243 kB)
# Installing collected packages: tifffile, lazy-loader, imageio, scikit-image
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-image]0m 3/4 [scikit-image]
# Successfully installed imageio-2.37.4 lazy-loader-0.5 scikit-image-0.26.0 tifffile-2026.3.3

# %%
# !python main.py --mode test_only --LR_path test_data --generator_path pretrained_models/SRGAN.pt
